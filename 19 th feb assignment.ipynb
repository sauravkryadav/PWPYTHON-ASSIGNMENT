# %%
"""Q1. What is Flask Framework? What are the advantages of Flask Framework?

ANS= Flask is a micro web framework written in Python that is used to build web applications. It is known for its simplicity and flexibility, making it a popular choice for building small to medium-sized web applications. Flask does not require particular tools or libraries, meaning that it can be used with any database or template engine.

Advantages of Flask Framework:

1.It is Lightweight and easy to use
2.It is Flexible and customizable
3.ItBuilt-in development server and debugger
4.It is Extensive documentation and active community support
5.It is Good for building small to medium-sized applications
6.It Supports extensions for added functionality
7.It Is Compatible with a wide range of databases and template engines"""

# %% [markdown]
# #question no 2.
# ![19feb_image.png](attachment:19feb_image.png)

# %% [markdown]
# #question no 3
#
# ![19feb_image3.png](attachment:19feb_image3.png)

# %%
"""Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function

ANS= The url_for() function is used in Flask for URL building. It generates a URL for a given endpoint with the given arguments."""

#code 
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/hello/<name>')
def hello(name):
    return 'Hello, %s!' % name

with app.test_request_context():
    print(url_for('hello', name='John'))

if __name__ == '__main__':
    app.run()
# Out:
# /hello/John
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [19/Mar/2023 14:36:01] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [19/Mar/2023 14:36:01] "GET /favicon.ico HTTP/1.1" 404 -
