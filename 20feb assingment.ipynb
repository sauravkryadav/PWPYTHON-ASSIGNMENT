# %%
"""Q1. Explain get and post method?

ans= The Get and Poat method are HTTP request methods used for different purposes:-

1. GET Method:- This method is used to retrive information from the server .
the data is sent in the url as a query string. This method is considered safe as it does not modify any data on the server.

2.POST Method:- This method is used to send data to the server to be proposed.
The data is sent in the request body, which can be in vatious formats such as JSON,XML Etc."""

# %%
"""Q2. Why is request used in falsk?

ans= IN flask a reqest is used to handle incoming client requset to the server.
it allows the server to recive data from the client , such as from of
submission or JSON data, and process it accordingly.
the request object provides access to the request data and metadata, such as header and cookies."""

# %%
"""Q3. Why is rediret()used in flask?

ANS= The redirect() function in Flask is used to redirect the client to a different URL.
This can be useful when handling form submissions or authentication, where the client needs to be redirected to a different page after a successful action.
The redirect() function sends a HTTP 302 status code to the client, indicating a temporary redirect."""
# Out:
# 'Q3. Why is rediret()used in flask?\n\nANS= The redirect() function in Flask is used to redirect the client to a different URL.\nThis can be useful when handling form submissions or authentication, where the client needs to be redirected to a different page after a successful action.\nThe redirect() function sends a HTTP 302 status code to the client, indicating a temporary redirect.'

# %%
"""Q.4 what are templates in falsk? why is the render_template() function is used?

ANS=emplates in Flask are HTML files that are used to generate dynamic web pages. They can contain placeholders for variables and logic that is executed by the server when rendering the template.

The render_template() function in Flask is used to render a template with the provided variables. It takes the name of the template file and the variables as arguments and returns the rendered HTML page. """

# %%
"""Q.5 Answe below"""

# %% [markdown]
# ![postman.png](attachment:postman.png)
